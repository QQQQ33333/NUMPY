# %% [markdown]
# As a culminating project, you'll be working with a dataset from ABC company, consisting of 458 rows and 9 columns. The company requires a comprehensive report detailing information about their employees across various teams. Your tasks include preprocessing the dataset, analyzing the data, and presenting your findings graphically. Here's a breakdown of what you need to do:
#
# Preprocessing:
# Correct the data in the "height" column by replacing it with random numbers between 150 and 180. Ensure data consistency and integrity before proceeding with analysis. (1 mark)
#
# Analysis Tasks:
# 1. Determine the distribution of employees across each team and calculate the percentage split relative to the total number of employees. (2 marks)
# 2. Segregate employees based on their positions within the company. (2 marks)
# 3. Identify the predominant age group among employees. (2 marks)
# 4. Discover which team and position have the highest salary expenditure. (2 marks)
# 5. Investigate if there's any correlation between age and salary, and represent it visually. (2 marks)
#
# Graphical Representation:
# For each of the five analysis tasks, create appropriate visualizations to present your findings effectively.

# %%
import pandas as pd

# %%
ABC=pd.read_csv('//content//myexcel - myexcel.csv.csv')
ABC
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
ABC["Height"].value_counts()
# Out:
# Height
# 06-Sep    59
# 06-Oct    47
# 06-Jul    45
# 06-Aug    43
# 06-Jun    42
# 06-Nov    40
# 06-Mar    33
# 06-May    32
# 06-Apr    29
# 7-0       27
# 06-Jan    16
# 06-Feb    16
# 6-0       10
# 07-Jan     7
# 07-Mar     5
# 05-Nov     3
# 07-Feb     3
# 05-Sep     1
# Name: count, dtype: int64

# %%
ABC['Height'].replace({"06-Sep":165,
                            "06-Oct":175,
                            "06-Jul":160,
                            "06-Aug":170,
                            "06-Jun":177,
                            "06-Nov":179,
                            "06-Mar":151,
                            "06-May":154,
                            "06-Apr":155,
                            "7-0":177,
                            "06-Jan":164,
                            "06-Feb":171,
                            "6-0":178,
                            "07-Jan":174,
                            "07-Mar":156,
                            "05-Nov":174,
                            "07-Feb":167,
                            "05-Sep":158
                           },inplace=True)
ABC
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     171     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     177     235
# 2     John Holland  Boston Celtics      30       SG   27     154     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     154     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     175     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     151     203
# 454      Raul Neto       Utah Jazz      25       PG   24     164     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     156     256
# 456    Jeff Withey       Utah Jazz      24        C   26     177     231
# 457       Priyanka       Utah Jazz      34        C   25     156     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
ABC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    int64
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 32.3+ KB

# %%
ABC.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
com=ABC.fillna(method="ffill")
com
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     171     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     177     235
# 2     John Holland  Boston Celtics      30       SG   27     154     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     154     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     175     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     151     203
# 454      Raul Neto       Utah Jazz      25       PG   24     164     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     156     256
# 456    Jeff Withey       Utah Jazz      24        C   26     177     231
# 457       Priyanka       Utah Jazz      34        C   25     156     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
com.isnull().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# College     0
# Salary      0
# dtype: int64

# %%
com.duplicated().sum()
# Out:
# 0

# %% [markdown]
# 1.
# Determine the distribution of employees across each team and calculate the percentage split relative to the total number of employees.

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
team=com["Team"].value_counts()
team
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=team,color ='orchid')
plt.title('Distribution of employees  across team',color='olive')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Only one team named 'New Orleans Pelicans' has highest no of employees that is 19.
#
# Most of the team (23 team) has 15 no of employees.
#
# 2 team named 'Orlando Magic and Minnesota Timberwolves ' has lowest no of employees that is 14.
#
# Generally we can say that almost team got around 15 employees in their team.

# %%
total_employees = len(com)
percentage_split = (team / total_employees) * 100
percentage_split
# Out:
# Team
# New Orleans Pelicans      4.148472
# Memphis Grizzlies         3.930131
# Utah Jazz                 3.493450
# New York Knicks           3.493450
# Milwaukee Bucks           3.493450
# Brooklyn Nets             3.275109
# Portland Trail Blazers    3.275109
# Oklahoma City Thunder     3.275109
# Denver Nuggets            3.275109
# Washington Wizards        3.275109
# Miami Heat                3.275109
# Charlotte Hornets         3.275109
# Atlanta Hawks             3.275109
# San Antonio Spurs         3.275109
# Houston Rockets           3.275109
# Boston Celtics            3.275109
# Indiana Pacers            3.275109
# Detroit Pistons           3.275109
# Cleveland Cavaliers       3.275109
# Chicago Bulls             3.275109
# Sacramento Kings          3.275109
# Phoenix Suns              3.275109
# Los Angeles Lakers        3.275109
# Los Angeles Clippers      3.275109
# Golden State Warriors     3.275109
# Toronto Raptors           3.275109
# ...

# %%
team.describe()
# Out:
# count    30.000000
# mean     15.266667
# std       0.980265
# min      14.000000
# 25%      15.000000
# 50%      15.000000
# 75%      15.000000
# max      19.000000
# Name: count, dtype: float64

# %%
plt.pie(team,labels=team.index,autopct="%1.1f%%",radius=2)
plt.title("Percentage of Employee Distribution by Team ",loc='center',color='w')
plt.show()

# %% [markdown]
# Only one team named 'New Orleans Pelicans' has the highest percentage split according to no. of employees in the company among all other team, that is 4.1%.
#
# Most of the team (23 team) has percentage split 3.3%.
#
# 2 team named 'Orlando Magic and
# Minnesota Timberwolves ' has lowest percentage split 3.1%
# Generally we can say that almost team got around 3.3% of employees in their team according to total no. of employees in the company.

# %% [markdown]
# 2. Segregate employees based on their positions within the company.

# %%
com.sort_values(by='Position')
# Out:
#                 Name               Team  Number Position  Age  Height  Weight  \
# 457         Priyanka          Utah Jazz      34        C   25     156     231
# 135    Alan Williams       Phoenix Suns      15        C   23     170     260
# 321   Tiago Splitter      Atlanta Hawks      11        C   31     179     245
# 322   Walter Tavares      Atlanta Hawks      22        C   24     156     260
# 128         Alex Len       Phoenix Suns      21        C   22     174     260
# ..               ...                ...     ...      ...  ...     ...     ...
# 325     Troy Daniels  Charlotte Hornets      30       SG   24     155     205
# 324    Nicolas Batum  Charlotte Hornets       5       SG   27     170     200
# 249     James Harden    Houston Rockets      13       SG   26     154     220
# 317  Lamar Patterson      Atlanta Hawks      13       SG   24     154     225
# 219  Khris Middleton    Milwaukee Bucks      22       SG   24     170     234
#
# ...

# %%
pos=com['Position'].value_counts()
pos
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
sns.barplot(data=pos,color='coral')
plt.title('No. Of EMPLOYEE-POSITION GRAPH',loc='right',color='maroon')
plt.fonts={"family":"monospace",'color':"g","size":25}
plt.xlabel("POSITION",loc="center")
plt.ylabel("COUNT",loc="center")
plt.show()

# %% [markdown]
# 100+ employees are working as SG in this company. Most of the employees are SG.
#
# Comparatively very few employees are working as C. That is below 80.

# %%
com.loc[com['Position']=='C']
# Out:
#                 Name                    Team  Number Position  Age  Height  \
# 7       Kelly Olynyk          Boston Celtics      41        C   25     177
# 10   Jared Sullinger          Boston Celtics       7        C   24     165
# 14      Tyler Zeller          Boston Celtics      44        C   26     177
# 23       Brook Lopez           Brooklyn Nets      11        C   28     177
# 27        Henry Sims           Brooklyn Nets      14        C   26     175
# ..               ...                     ...     ...      ...  ...     ...
# 439    Mason Plumlee  Portland Trail Blazers      24        C   26     179
# 447      Rudy Gobert               Utah Jazz      27        C   23     174
# 455     Tibor Pleiss               Utah Jazz      21        C   26     156
# 456      Jeff Withey               Utah Jazz      24        C   26     177
# 457         Priyanka               Utah Jazz      34        C   25     156
#
#      Weight         College      Salary
# ...

# %%
com.loc[com['Position']=='SF']
# Out:
#                        Name                    Team  Number Position  Age  \
# 1               Jae Crowder          Boston Celtics      99       SF   25
# 32   Thanasis Antetokounmpo         New York Knicks      43       SF   23
# 33          Carmelo Anthony         New York Knicks       7       SF   32
# 35         Cleanthony Early         New York Knicks      11       SF   25
# 42             Lance Thomas         New York Knicks      42       SF   28
# ..                      ...                     ...     ...      ...  ...
# 428         Al-Farouq Aminu  Portland Trail Blazers       8       SF   25
# 432        Maurice Harkless  Portland Trail Blazers       4       SF   23
# 448          Gordon Hayward               Utah Jazz      20       SF   26
# 450              Joe Ingles               Utah Jazz       2       SF   28
# 451           Chris Johnson               Utah Jazz      23       SF   26
#
#      Height  Weight        College      Salary
# ...

# %%
com.loc[com['Position']=='PG']
# Out:
#               Name                    Team  Number Position  Age  Height  \
# 0    Avery Bradley          Boston Celtics       0       PG   25     171
# 8     Terry Rozier          Boston Celtics      12       PG   22     171
# 9     Marcus Smart          Boston Celtics      36       PG   22     155
# 11   Isaiah Thomas          Boston Celtics       4       PG   27     158
# 19    Jarrett Jack           Brooklyn Nets       2       PG   32     151
# ..             ...                     ...     ...      ...  ...     ...
# 440  Brian Roberts  Portland Trail Blazers       2       PG   30     164
# 443     Trey Burke               Utah Jazz       3       PG   23     164
# 445     Dante Exum               Utah Jazz      11       PG   20     177
# 453   Shelvin Mack               Utah Jazz       8       PG   26     151
# 454      Raul Neto               Utah Jazz      25       PG   24     164
#
#      Weight         College     Salary
# 0       180           Texas  7730337.0
# ...

# %%
com.loc[com['Position']=='PF']
# Out:
#                  Name                    Team  Number Position  Age  Height  \
# 4       Jonas Jerebko          Boston Celtics       8       PF   29     175
# 5        Amir Johnson          Boston Celtics      90       PF   29     165
# 6       Jordan Mickey          Boston Celtics      55       PF   21     170
# 24   Chris McCullough           Brooklyn Nets       1       PF   21     179
# 25        Willie Reed           Brooklyn Nets      33       PF   26     175
# ..                ...                     ...     ...      ...  ...     ...
# 435    Meyers Leonard  Portland Trail Blazers      11       PF   24     174
# 441       Noah Vonleh  Portland Trail Blazers      21       PF   20     165
# 442     Trevor Booker               Utah Jazz      33       PF   28     170
# 446    Derrick Favors               Utah Jazz      15       PF   24     175
# 452        Trey Lyles               Utah Jazz      41       PF   20     175
#
#      Weight        College      Salary
# ...

# %%
com.loc[com['Position']=='SG']
# Out:
#                  Name                    Team  Number Position  Age  Height  \
# 2        John Holland          Boston Celtics      30       SG   27     154
# 3         R.J. Hunter          Boston Celtics      28       SG   22     154
# 12        Evan Turner          Boston Celtics      11       SG   27     160
# 13        James Young          Boston Celtics      13       SG   20     177
# 15   Bojan Bogdanovic           Brooklyn Nets      44       SG   27     170
# ..                ...                     ...     ...      ...  ...     ...
# 433  Gerald Henderson  Portland Trail Blazers       9       SG   28     154
# 437     C.J. McCollum  Portland Trail Blazers       3       SG   24     155
# 438      Luis Montero  Portland Trail Blazers      44       SG   23     160
# 444        Alec Burks               Utah Jazz      10       SG   24     177
# 449       Rodney Hood               Utah Jazz       5       SG   23     170
#
#      Weight            College     Salary
# ...

# %% [markdown]
# ? Identify the predominant age group among employees.

# %%
age=com['Age'].value_counts()
age
# Out:
# Age
# 24    47
# 25    46
# 27    41
# 23    41
# 26    36
# 28    31
# 30    31
# 29    28
# 22    26
# 31    22
# 20    19
# 21    19
# 33    14
# 32    13
# 34    10
# 36    10
# 35     9
# 37     4
# 38     4
# 40     3
# 39     2
# 19     2
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=age,color='m')
plt.title('AGE GROUP CHART',color='purple',loc='center')
plt.show()

# %% [markdown]
# Predominant age group among employees is "24". There are 47 employees are 24 years old.From this bar diagram, we can see that most of the employees are youth(in between 22 and 30 years).This implies the company gives more opportunity to freshers and young peoples.

# %% [markdown]
#  ? Discover which team and position have the highest salary expenditure.

# %%
sal=com.sort_values(by='Salary',ascending=False)
sal
# Out:
#                        Name                  Team  Number Position  Age  \
# 109             Kobe Bryant    Los Angeles Lakers      24       SF   37
# 169            LeBron James   Cleveland Cavaliers      23       SF   31
# 33          Carmelo Anthony       New York Knicks       7       SF   32
# 251           Dwight Howard       Houston Rockets      12        C   30
# 339              Chris Bosh            Miami Heat       1       PF   32
# ..                      ...                   ...     ...      ...  ...
# 175            Jordan McRae   Cleveland Cavaliers      12       SG   25
# 135           Alan Williams          Phoenix Suns      15        C   23
# 130            Phil Pressey          Phoenix Suns      25       PG   25
# 291         Orlando Johnson  New Orleans Pelicans       0       SG   27
# 32   Thanasis Antetokounmpo       New York Knicks      43       SF   23
#
#      Height  Weight           College      Salary
# 109     177     212          Stanford  25000000.0
# ...

# %%
top5=sal.head(5)
top5
# Out:
#                 Name                 Team  Number Position  Age  Height  \
# 109      Kobe Bryant   Los Angeles Lakers      24       SF   37     177
# 169     LeBron James  Cleveland Cavaliers      23       SF   31     170
# 33   Carmelo Anthony      New York Knicks       7       SF   32     170
# 251    Dwight Howard      Houston Rockets      12        C   30     179
# 339       Chris Bosh           Miami Heat       1       PF   32     179
#
#      Weight       College      Salary
# 109     212      Stanford  25000000.0
# 169     250          Duke  22970500.0
# 33      240      Syracuse  22875000.0
# 251     265    Louisville  22359364.0
# 339     235  Georgia Tech  22192730.0

# %%
sns.barplot(x='Team',y='Salary',data=top5,hue='Position')
plt.title('TOP5 SALARY GRAPH of TEAMS',color='red')
plt.xticks(rotation=45)
plt.show()

# %%
com.loc[com['Salary']==com['Salary'].max()]
# Out:
#             Name                Team  Number Position  Age  Height  Weight  \
# 109  Kobe Bryant  Los Angeles Lakers      24       SF   37     177     212
#
#       College      Salary
# 109  Stanford  25000000.0

# %% [markdown]
# Kobe Bryant	is member of team 'Los Angeles Lakers' has highest salary with SG position .
# According to above graph,top 3 salary is given to SG positioned employees.

# %% [markdown]
# ? Investigate if there's any correlation between age and salary, and represent it visually.

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='Age',y='Salary',data=com)
plt.title('Correlation between Age - Salary')
plt.show()

# %% [markdown]
# Most of the employees aged between 24 and 32 years got 1M+ salary than that of others. Age below 24 and above 32 were getting around 1M salary, which indicates most of the freshers and the mid-aged may be less efficient than that of others.
#
# **Yaa,there is a correlation between age and salary.**
